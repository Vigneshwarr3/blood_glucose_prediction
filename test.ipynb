# %%
import xml.etree.ElementTree as ET
from collections import defaultdict
import os

# %%
tree = ET.parse('data_xml/559-ws-testing.xml')

# %%
root = tree.getroot()

# %%
unique_elements = []
for element in root.iter():
        if element.tag not in unique_elements:
            unique_elements.append(element.tag)
            print(element.tag)
# Out:
# patient
# glucose_level
# event
# finger_stick
# basal
# temp_basal
# bolus
# meal
# sleep
# work
# stressors
# hypo_event
# illness
# exercise
# basis_heart_rate
# basis_gsr
# basis_skin_temperature
# basis_air_temperature
# basis_steps
# basis_sleep

# %%
from helper_functions import *
df = extract_all_features_to_csv('data_xml/559-ws-testing.xml')
# Out:
# ✅ Successfully extracted features!
#    Input file: data_xml/559-ws-testing.xml
#    Output file: data_xml/559-ws-testing_all_features.csv
#    Total rows: 6734
#    Columns: timestamp, patient, glucose_level, finger_stick, basal, meal_type, meal_carbs, exercise_intensity, exercise_duration, basis_heart_rate, basis_gsr, basis_skin_temperature, basis_air_temperature, basis_steps

# %%
import importlib
import helper_functions
importlib.reload(helper_functions)
from helper_functions import extract_duration_events_to_csv

# Extract duration events
df_duration = extract_duration_events_to_csv('data_xml/559-ws-testing.xml')

# %%
df_duration.head()
# Out:
#   patient           timestamp  duration_minutes sleep basis_sleep  \
# 0     559 2022-01-17 21:30:00             480.0     3        None
# 1     559 2022-01-18 06:26:05               0.0  None        None
# 2     559 2022-01-18 11:10:13               0.0  None        None
# 3     559 2022-01-18 13:30:00               0.0  None        None
# 4     559 2022-01-18 17:55:42               0.0  None        None
#
#   work_intensity bolus_type bolus_dose bolus_carb_input temp_basal_value
# 0           None       None       None             None             None
# 1           None     normal        6.3               40             None
# 2           None     normal        3.3               30             None
# 3              5       None       None             None             None
# 4           None     normal        0.2                0             None

# %%
for file in os.listdir(os.getcwd()):
    if file.endswith('.xml'):
        extract_all_features_to_csv(file)

# %%
df.head()
# Out:
#             timestamp patient glucose_level finger_stick basal meal_type  \
# 0 2022-01-18 00:00:00     559          None         None  None      None
# 1 2022-01-18 00:01:00     559           179         None  None      None
# 2 2022-01-18 00:04:00     559          None         None  None      None
# 3 2022-01-18 00:05:00     559          None         None  None      None
# 4 2022-01-18 00:06:00     559           183         None  None      None
#
#   meal_carbs exercise_intensity exercise_duration basis_heart_rate basis_gsr  \
# 0       None               None              None               57      None
# 1       None               None              None             None   1.83E-4
# 2       None               None              None             None      None
# 3       None               None              None               57      None
# 4       None               None              None             None   1.82E-4
#
#   basis_skin_temperature basis_air_temperature basis_steps
# 0                   92.3                  89.6        None
# 1                   None                  None        None
# 2                   None                  None           0
# 3                   92.3                  89.6        None
# 4                   None                  None        None

# %%
df_duration.head()
# Out:
#   patient                date  duration_minutes sleep basis_sleep  \
# 0     559 2022-01-17 21:30:00             480.0     3        None
# 1     559 2022-01-18 06:26:05               0.0  None        None
# 2     559 2022-01-18 11:10:13               0.0  None        None
# 3     559 2022-01-18 13:30:00               0.0  None        None
# 4     559 2022-01-18 17:55:42               0.0  None        None
#
#   work_intensity bolus_type bolus_dose bolus_carb_input temp_basal_value
# 0           None       None       None             None             None
# 1           None     normal        6.3               40             None
# 2           None     normal        3.3               30             None
# 3              5       None       None             None             None
# 4           None     normal        0.2                0             None

# %%
df_new = pd.merge(df, df_duration, on=['timestamp', 'patient'], how='left')

# %%
df_new.head()
# Out:
#             timestamp patient glucose_level finger_stick basal meal_type  \
# 0 2022-01-18 00:00:00     559          None         None  None      None
# 1 2022-01-18 00:01:00     559           179         None  None      None
# 2 2022-01-18 00:04:00     559          None         None  None      None
# 3 2022-01-18 00:05:00     559          None         None  None      None
# 4 2022-01-18 00:06:00     559           183         None  None      None
#
#   meal_carbs exercise_intensity exercise_duration basis_heart_rate  ...  \
# 0       None               None              None               57  ...
# 1       None               None              None             None  ...
# 2       None               None              None             None  ...
# 3       None               None              None               57  ...
# 4       None               None              None             None  ...
#
#   basis_air_temperature basis_steps duration_minutes sleep  basis_sleep  \
# 0                  89.6        None              NaN   NaN          NaN
# 1                  None        None              NaN   NaN          NaN
# 2                  None           0              NaN   NaN          NaN
# 3                  89.6        None              NaN   NaN          NaN
# 4                  None        None              NaN   NaN          NaN
#
#   work_intensity bolus_type bolus_dose bolus_carb_input temp_basal_value
# 0            NaN        NaN        NaN              NaN              NaN
# 1            NaN        NaN        NaN              NaN              NaN
# 2            NaN        NaN        NaN              NaN              NaN
# 3            NaN        NaN        NaN              NaN              NaN
# 4            NaN        NaN        NaN              NaN              NaN
#
# [5 rows x 22 columns]

# %%
df.to_csv('training_data.csv', index=False)

# %%
import pandas as pd
from timeGAN import train_time_series_gan, generate_synthetic_data

# Step 1: Load your training data
df = pd.read_csv('training_data.csv')
df['timestamp'] = pd.to_datetime(df['timestamp'])

# Step 2: Select features to generate
# Based on your CSV columns
features = [
    'glucose_level', 'finger_stick', 'basal', 'temp_basal', 'bolus', 'meal',
    'sleep', 'work', 'stressors', 'hypo_event', 'illness', 'exercise',
    'basis_heart_rate', 'basis_gsr', 'basis_skin_temperature',
    'basis_air_temperature', 'basis_steps', 'basis_sleep'
]

# Filter to only include features that exist in your DataFrame
features = [f for f in features if f in df.columns]
print(f"Using {len(features)} features: {features}")

# Step 3: Train the GAN
print("\n" + "="*80)
print("TRAINING TIME SERIES GAN")
print("="*80)

gan, scaler, feature_names = train_time_series_gan(
    df,
    features=features,
    seq_len=24,        # 24 timesteps = 2 hours (assuming 5-min intervals)
    epochs=200,        # Number of training epochs
    batch_size=64,     # Batch size
    hidden_dim=128,    # LSTM hidden dimension
    num_layers=2       # Number of LSTM layers
)

# Step 4: Generate synthetic data
print("\n" + "="*80)
print("GENERATING SYNTHETIC DATA")
print("="*80)

df_synthetic = generate_synthetic_data(
    gan, 
    scaler, 
    feature_names,
    n_samples=100,     # Number of sequences to generate
    seq_len=24         # Length of each sequence
)

# Step 5: Save synthetic data
df_synthetic.to_csv('synthetic_patient_data.csv', index=False)
print(f"\n✅ Generated {len(df_synthetic)} synthetic data points")
print("   Saved to 'synthetic_patient_data.csv'")
# Out:
# Using 8 features: ['glucose_level', 'finger_stick', 'basal', 'basis_heart_rate', 'basis_gsr', 'basis_skin_temperature', 'basis_air_temperature', 'basis_steps']
#
# ================================================================================
# TRAINING TIME SERIES GAN
# ================================================================================
# ================================================================================
# TIME SERIES GAN TRAINING PIPELINE
# ================================================================================
#
# [1/4] Preparing data...
#    Dataset size: 6711
#    Features: ['glucose_level', 'finger_stick', 'basal', 'basis_heart_rate', 'basis_gsr', 'basis_skin_temperature', 'basis_air_temperature', 'basis_steps']
#    Sequence length: 24
#
# [2/4] Initializing Time Series GAN...
# /Users/vigneshwar_r/Downloads/Applied Data Science/Cloud Computing/Project/blood_glucose_prediction/timeGAN.py:56: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_features = df_features.fillna(method='ffill', limit=10).fillna(method='bfill', limit=10).fillna(0)
#    Device: cpu
#    Input dimension: 8
#
# [3/4] Training GAN...
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 26
#      23 print("TRAINING TIME SERIES GAN")
#      24 print("="*80)
# ---> 26 gan, scaler, feature_names = train_time_series_gan(
#      27     df,
#      28     features=features,
#      29     seq_len=24,        # 24 timesteps = 2 hours (assuming 5-min intervals)
#      30     epochs=200,        # Number of training epochs
#      31     batch_size=64,     # Batch size
#      32     hidden_dim=128,    # LSTM hidden dimension
#      33     num_layers=2       # Number of LSTM layers
#      34 )
#      36 # Step 4: Generate synthetic data
#      37 print("\n" + "="*80)
#
# File ~/Downloads/Applied Data Science/Cloud Computing/Project/blood_glucose_prediction/timeGAN.py:409, in train_time_series_gan(df, features, seq_len, epochs, batch_size, hidden_dim, num_layers)
#     407 # 3. Train GAN
#     408 print("\n[3/4] Training GAN...")
# --> 409 gan.train(dataloader, epochs=epochs, seq_len=seq_len)
#     411 # 4. Save model
#     412 print("\n[4/4] Saving model...")
#
# File ~/Downloads/Applied Data Science/Cloud Computing/Project/blood_glucose_prediction/timeGAN.py:280, in TimeSeriesGAN.train(self, dataloader, epochs, seq_len, d_steps, g_steps)
#     278 fake_data, _ = self.generator(noise)
#     279 fake_labels = torch.zeros(batch_size, 1).to(self.device)
# --> 280 fake_output = self.discriminator(fake_data.detach())
#     281 d_loss_fake = self.criterion(fake_output, fake_labels)
#     283 # Total discriminator loss
#
# File ~/Downloads/Applied Data Science/Cloud Computing/Project/blood_glucose_prediction/blood_glucose/lib/python3.10/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/Downloads/Applied Data Science/Cloud Computing/Project/blood_glucose_prediction/blood_glucose/lib/python3.10/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/Downloads/Applied Data Science/Cloud Computing/Project/blood_glucose_prediction/timeGAN.py:170, in Discriminator.forward(self, x)
#     163 """
#     164 Args:
#     165     x: time series tensor (batch_size, seq_len, input_dim)
#     166 Returns:
#     167     probability that input is real
#     168 """
#     169 # Embed input
# --> 170 embedded = self.embedding(x)
#     172 # LSTM forward pass
#     173 lstm_out, _ = self.lstm(embedded)
#
# File ~/Downloads/Applied Data Science/Cloud Computing/Project/blood_glucose_prediction/blood_glucose/lib/python3.10/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/Downloads/Applied Data Science/Cloud Computing/Project/blood_glucose_prediction/blood_glucose/lib/python3.10/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/Downloads/Applied Data Science/Cloud Computing/Project/blood_glucose_prediction/blood_glucose/lib/python3.10/site-packages/torch/nn/modules/linear.py:134, in Linear.forward(self, input)
#     130 def forward(self, input: Tensor) -> Tensor:
#     131     """
#     132     Runs the forward pass.
#     133     """
# --> 134     return F.linear(input, self.weight, self.bias)
#
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (1536x2 and 8x128)
